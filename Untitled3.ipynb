# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder

from yellowbrick.classifier import ROCAUC
#from yellowbrick.datasets import load_game

# Load multi-class classification dataset
#X, y = load_game()

data = pd.read_csv(r"C:\Users\Owner\OneDrive - University of Bradford\Dissertation\Data\research_dataset.csv")

data["UUU"] = pd.to_numeric(data["UUU"], errors = 'coerce')
data["UUC"] = pd.to_numeric(data["UUC"], errors = 'coerce')

data = data.replace(np.nan, 0, regex=True)

data = data.reset_index()

data.head(2)


X =  np.array(data.iloc[:, 6:69])
y = np.array(data.iloc[:, 1])


# Encode the non-numeric columns
X = OrdinalEncoder().fit_transform(X)
y = LabelEncoder().fit_transform(y)

# Create the train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Instaniate the classification model and visualizer

#model = XGBClassifier()
from xgboost import XGBClassifier
model = XGBClassifier(learning_rate=0.1,
                     max_depth=5,
                     estimator=5000,
                     subsample=0.5,
                     colsample_bytree=0.5,
                     eval_metric='auc',
                     verbosity=1)
eval_set = [(X_test, y_test)]
model.fit(X_train, y_train, early_stopping_rounds=10,eval_metric="mlogloss", eval_set=eval_set, verbose=True)

visualizer = ROCAUC(model, classes=["bct", "pln", "Inv", "Vrt"])

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show()                       # Finalize and render the figure
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# [15:34:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "estimator" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-mlogloss:1.27277
# [1]	validation_0-mlogloss:1.17182
# C:\Users\Owner\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [2]	validation_0-mlogloss:1.08495
# [3]	validation_0-mlogloss:1.01149
# [4]	validation_0-mlogloss:0.94503
# [5]	validation_0-mlogloss:0.88616
# [6]	validation_0-mlogloss:0.83432
# [7]	validation_0-mlogloss:0.78695
# [8]	validation_0-mlogloss:0.74452
# [9]	validation_0-mlogloss:0.70378
# [10]	validation_0-mlogloss:0.66789
# [11]	validation_0-mlogloss:0.63677
# [12]	validation_0-mlogloss:0.60781
# [13]	validation_0-mlogloss:0.58028
# [14]	validation_0-mlogloss:0.55351
# [15]	validation_0-mlogloss:0.53208
# [16]	validation_0-mlogloss:0.51231
# [17]	validation_0-mlogloss:0.49307
# [18]	validation_0-mlogloss:0.47507
# [19]	validation_0-mlogloss:0.45766
# [20]	validation_0-mlogloss:0.44160
# [21]	validation_0-mlogloss:0.42697
# [22]	validation_0-mlogloss:0.41405
# [23]	validation_0-mlogloss:0.40145
# [24]	validation_0-mlogloss:0.39057
# [25]	validation_0-mlogloss:0.37896
# [26]	validation_0-mlogloss:0.36830
# [27]	validation_0-mlogloss:0.35839
# [28]	validation_0-mlogloss:0.34910
# [29]	validation_0-mlogloss:0.33987
# [30]	validation_0-mlogloss:0.33186
# [31]	validation_0-mlogloss:0.32323
# [32]	validation_0-mlogloss:0.31553
# [33]	validation_0-mlogloss:0.30850
# [34]	validation_0-mlogloss:0.30151
# [35]	validation_0-mlogloss:0.29435
# [36]	validation_0-mlogloss:0.28794
# [37]	validation_0-mlogloss:0.28252
# [38]	validation_0-mlogloss:0.27775
# [39]	validation_0-mlogloss:0.27340
# [40]	validation_0-mlogloss:0.26768
# [41]	validation_0-mlogloss:0.26259
# [42]	validation_0-mlogloss:0.25816
# [43]	validation_0-mlogloss:0.25386
# [44]	validation_0-mlogloss:0.25007
# [45]	validation_0-mlogloss:0.24625
# [46]	validation_0-mlogloss:0.24240
# [47]	validation_0-mlogloss:0.23896
# [48]	validation_0-mlogloss:0.23506
# [49]	validation_0-mlogloss:0.23219
# [50]	validation_0-mlogloss:0.22905
# [51]	validation_0-mlogloss:0.22623
# [52]	validation_0-mlogloss:0.22344
# [53]	validation_0-mlogloss:0.22036
# [54]	validation_0-mlogloss:0.21766
# [55]	validation_0-mlogloss:0.21464
# [56]	validation_0-mlogloss:0.21159
# [57]	validation_0-mlogloss:0.20967
# [58]	validation_0-mlogloss:0.20762
# [59]	validation_0-mlogloss:0.20528
# [60]	validation_0-mlogloss:0.20305
# [61]	validation_0-mlogloss:0.20068
# [62]	validation_0-mlogloss:0.19830
# [63]	validation_0-mlogloss:0.19637
# [64]	validation_0-mlogloss:0.19425
# [65]	validation_0-mlogloss:0.19234
# [66]	validation_0-mlogloss:0.19009
# [67]	validation_0-mlogloss:0.18804
# [68]	validation_0-mlogloss:0.18630
# [69]	validation_0-mlogloss:0.18500
# [70]	validation_0-mlogloss:0.18302
# [71]	validation_0-mlogloss:0.18132
# [72]	validation_0-mlogloss:0.17934
# [73]	validation_0-mlogloss:0.17753
# [74]	validation_0-mlogloss:0.17542
# [75]	validation_0-mlogloss:0.17426
# [76]	validation_0-mlogloss:0.17273
# [77]	validation_0-mlogloss:0.17083
# [78]	validation_0-mlogloss:0.16927
# [79]	validation_0-mlogloss:0.16825
# [80]	validation_0-mlogloss:0.16711
# [81]	validation_0-mlogloss:0.16576
# [82]	validation_0-mlogloss:0.16436
# [83]	validation_0-mlogloss:0.16366
# [84]	validation_0-mlogloss:0.16237
# [85]	validation_0-mlogloss:0.16164
# [86]	validation_0-mlogloss:0.16084
# [87]	validation_0-mlogloss:0.15979
# [88]	validation_0-mlogloss:0.15891
# [89]	validation_0-mlogloss:0.15773
# [90]	validation_0-mlogloss:0.15702
# [91]	validation_0-mlogloss:0.15609
# [92]	validation_0-mlogloss:0.15528
# [93]	validation_0-mlogloss:0.15469
# [94]	validation_0-mlogloss:0.15388
# [95]	validation_0-mlogloss:0.15309
# [96]	validation_0-mlogloss:0.15230
# [97]	validation_0-mlogloss:0.15119
# [98]	validation_0-mlogloss:0.15036
# [99]	validation_0-mlogloss:0.14963
# <AxesSubplot:title={'center':'ROC Curves for XGBClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %%
model = XGBClassifier(learning_rate=0.1,
                     max_depth=5,
                     estimator=5000,
                     subsample=0.5,
                     colsample_bytree=0.5,
                     eval_metric='auc',
                     verbosity=1)
eval_set = [(x_test, y_test)]
model.fit(x_train, y_train, early_stopping_rounds=10,eval_metric="mlogloss", eval_set=eval_set, verbose=True)
